# %% [markdown]
# ## Initial Promopt

# %%
import pdfplumber
from transformers import pipeline

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
    return text

# Function to summarize text using Hugging Face transformer models (PyTorch backend)
def summarize_text_based_on_prompt(text, prompt, model="facebook/bart-large-cnn", max_length=200):
    summarizer = pipeline("summarization", model=model, framework="pt")  # Use PyTorch
    max_input_length = 1024  # Adjust based on model's max length
    text_chunks = [text[i:i+max_input_length] for i in range(0, len(text), max_input_length)]
    summaries = []
    for chunk in text_chunks:
        full_text_with_prompt = prompt + " " + chunk
        try:
            summary = summarizer(full_text_with_prompt, max_length=max_length, min_length=30, do_sample=False)
            if summary:
                summaries.append(summary[0]['summary_text'])
        except IndexError:
            summaries.append("Error: Summary index out of range.")
    return " ".join(summaries)

# Example usage
pdf_path = "/content/Blockchain_Technology_and_Artificial_Intelligence_.pdf"  # Your PDF file path
prompt = "Summarize the key findings of the paper."
text = extract_text_from_pdf(pdf_path)
print("Extracted text preview:")
print(text[:500])  # Print the first 500 characters to verify

summary = summarize_text_based_on_prompt(text, prompt)
print("Summary based on prompt:")
print(summary)
# Out:
# Extracted text preview:
# applied
# sciences
# Review
# Blockchain Technology and Artificial Intelligence Together: A
# Critical Review on Applications
# HamedTaherdoost
# DepartmentofArts,CommunicationsandSocialSciences,UniversityCanadaWest,Vancouver,BCV6Z0E5,
# Canada;hamed.taherdoost@gmail.com;Tel.:+1-236-889-5359
# Abstract: It is undeniable that the adoption of blockchain- and artificial intelligence (AI)-based
# paradigmsisproceedingatlightningspeed.Bothparadigmsprovidesomethingnewtothemarket,
# butthedegreeofnoveltyandcomplexityofeac
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Summary based on prompt:
# HamedTaherdoost: It is undeniable that the adoption of blockchain- and artificial intelligence (AI)-based technologies is proceeding at lightningspeed. Thiscriticalreviewcontains121 articles from therecentdecade. Summarize the key findings of the paper. eabilitytoreasonandmakedecisions and human-levelintellect. Blockchain technology has the potential to be very useful in eliminating the need for a centralauthorityfigure. Artificialintelligence(AI), whichgivesMachines the ability to learn from data, is anotherveryvisibleareathatisgainingalotoftraction. This article is an open access article. Summarize the key findings of the paper. informationinsmarthomes. The consensusreachedamongtheconditionsoftheCreativeCommons.nodesinablockchainensuresthat alltransactionsare recordedpermanently. The convergence of AI and blockchain is the subject of a new paper. The paper was published by the MIT Sloan School of Management. It was the first of its kind to be published by MIT Sloan. Blockchain technology allowsforthesafekeeping ofpatientrecords. Medicalprovidersmayaccesspatienthealthdataviathewalletwhenever needed. Integrating AI with a blockchain has been claimed to have far-reachingimplications. iverseas6Gnetworks, smartcities,banking,and driverless cars. Withoutrelyingonacentralizedauthority orintermediaries, thisenablesthesafeandreliabledistributionoflargedatasets foranalysis,learning,anddecisionmaking. Appl. Sci. 2022, 12, x FOR PEER REVIEW 3 of 21. Summarize the key findings of the paper. At IstuWdiyth ist ahse fuoltlmowosst. Aolrs itmudpyrowvainsgto theev aqluuaaltietyth oef cfuurtruernet rsetasetearocfhb. lTochkec shtaruincttuecrhen oofl tohgeycwuirtrhen at Istuwdiyth. The goal of this critical study was to evaluate the current state of blockchain technology. With the utmost seriousness, all the recent pertinent literature was carefully reviewed for this inquiry. Relevantdatabases werethoroughlysearched to provide a complete and concise evaluation of the research topics. About121 wereconsideredimportant(Figure2). Theformulationofthesearchstring was                . Bysearching“Artificialintelligence”                RQ4: What are the challenges in combining blockchains with AI? A holistic review of the literature necessitated an inclusive perspective. Throughout the study, Scopus sources were examined. Relevant databases were thoroughly searched. The results were published in the journal Appl.Sci.2022,12,12948.  353 Scopus results have been analyzed. Not all outstand-ggeennccee’s were included in the search criteria. A thorough literature search was carried out. The paper was published by the Proceedings of the National Academy of Sciences. It was the first paper of its kind to be published on the subject of artificial intelligence. The findings were published in the journal Artificial Intelligence. 2. Summarize the key findings of the paper. 3. Exclusion of book chapters, dissertations, conference proceedings, interview-based works, and reviews. 1. Summarize the key findings of the paper. 2. Theimportanceandapplications of the methods used in the study. 3. The implications of the findings. Summarize key findings of the paper. Summarize the key findings from the study of the human brain. The study was published in the Proceedings of the National Academy of Sciences. The paper was published by the National Institutes of Health. Thereare121articlesinthiscriticalreview. Thepublicationsthatwereselectedarelisted alongside the selected articles. The responses to the RQs from the critical review that came before are included below. In total, 353 items were generated by this search, and 232 of them were inspected. Computer science (84 articles) and engineering were the primary topics. There are 121 articles in this critical review. The publications that were selected are listed below, along with an explanation of the overall classification results. This critical analysis concludes the study of research papers combining AI and blockchains. The ...

# %% [markdown]
# ## Second Iterations

# %%
import pdfplumber
from transformers import pipeline

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
    return text

# Function to summarize text using Hugging Face transformer models (PyTorch backend)
def summarize_text_based_on_prompt(text, prompt, model="facebook/bart-large-cnn", max_length=200):
    summarizer = pipeline("summarization", model=model, framework="pt")  # Use PyTorch
    max_input_length = 1024  # Adjust based on model's max length
    text_chunks = [text[i:i+max_input_length] for i in range(0, len(text), max_input_length)]
    summaries = []
    for chunk in text_chunks:
        full_text_with_prompt = prompt + " " + chunk
        try:
            summary = summarizer(full_text_with_prompt, max_length=max_length, min_length=30, do_sample=False)
            if summary:
                summaries.append(summary[0]['summary_text'])
        except IndexError:
            summaries.append("Error: Summary index out of range.")
    return " ".join(summaries)

# Example usage
pdf_path = "/content/Blockchain_Technology_and_Artificial_Intelligence_.pdf"  # Your PDF file path
prompt = "Provide a concise summary of the methodology used in this research."
text = extract_text_from_pdf(pdf_path)
print("Extracted text preview:")
print(text[:500])  # Print the first 500 characters to verify

summary = summarize_text_based_on_prompt(text, prompt)
print("Summary based on prompt:")
print(summary)
# Out:
# Extracted text preview:
# applied
# sciences
# Review
# Blockchain Technology and Artificial Intelligence Together: A
# Critical Review on Applications
# HamedTaherdoost
# DepartmentofArts,CommunicationsandSocialSciences,UniversityCanadaWest,Vancouver,BCV6Z0E5,
# Canada;hamed.taherdoost@gmail.com;Tel.:+1-236-889-5359
# Abstract: It is undeniable that the adoption of blockchain- and artificial intelligence (AI)-based
# paradigmsisproceedingatlightningspeed.Bothparadigmsprovidesomethingnewtothemarket,
# butthedegreeofnoveltyandcomplexityofeac
# Summary based on prompt:
# HamedTaherdoost: It is undeniable that the adoption of blockchain- and artificial intelligence (AI)-based technologies is proceeding at lightningspeed. AIandblockchainsaretwoofthemosttalkedabouttechnologiesrightnow. Thiscriticalreviewcontains121articlesfromtherecentdecade that investigate the present situation and rationale of the AI and blockchain combination. Provide a concise summary of the methodology used in this research. eabilitytoreasonandmakedecisions and human-levelintellect. provide a concise summary of the methodology used in this research. Provide a brief description of the technology used in the research. Use the weekly Newsquiz to test your knowledge of stories you saw on this site. This article is an open access article. Provide a concise summary of the methodology used in this research. informationinsmarthomes                Copyright: © 2022 by the author.Licensee MDPI, Basel, Switzerland. Provide a concise summary of the methodology used in this research. wotechnologiesisthebasisfordecentralizedAI(blockchainsandAI)[11]. Inadistributedandintermediary-freemanner, itallowsfortheexecutionandstorageoftrustworthy, carefully tagged, and shared data. Blockchain technology allowsforthesafekeeping ofpatientrecords. Medicalprovidersmayaccesspatienthealthdataviathewalletwhenever needed. Integrating AI with a blockchain has been claimed to have far-reachingimplications. iverseas6Gnetworks,smartcities,banking,and driverlesscars. Withoutrelyingonacentralizedauthority orintermediaries, thisenablesthesafeandreliabledistributionoflargedatasets foranalysis,learning, anddecisionmaking. provide a concise summary of the methodology used in this research. teratureiscoveredindepthinthe secondpart. Inthe thirdsection,theliteratureon AIandblockchainintegrationiscovered. Thelastsection is the conclusion. For PEER REVIEW 3 of 21, visit: http://www.appl. Sci. 2022,12,12948. At IstuWdiyth ist ahse fuoltlmowosst. aolrs itmudpyrowvainsgto theev aqluuaaltietyth oef cfuurtruernet rsetasetearocfhb. lTochkec shtaruincttuecrhen oofl tohgey cwuirtrhen. The RQs’ details are as follows:1. Provide a concise summary of the methodology used in this research.2. The goal of this critical study was to evaluate the current state of blockchain technology. With the utmost seriousness, all the recent pertinent literature was carefully reviewed for this inquiry. The review strategy made extensive use of structured research and Scopus database. About121 wereconsideredimportant(Figure2). Theformulationofthesearchstring was                . Provide a concise summary of the methodology used in this research. teraturesearchwas                . Up to now, 353 Scopus results have been analyzed.  Provide a concise summary of the methodology used in this research. Throughout the study, Scopus sources were examined. Relevant databases were thoroughly searched. A holistic review of the literature required an inclusive perspective.  Provide a concise summary of the methodology used in this research. Up to now, 353 Scopus results have been analyzed. For several reasons, not all outstand-ggeennccee’” OORR ““AAII”” AANNDD � ‘“bblloocckkcchhaaiinn’ provide a concise summary of the methodology used in this research. Provide a concise description of the results of the study. Use this information to help people understand the findings of this study.  Provide a concise summary of the methodology used in this research. Exclusion of book chapters, dissertations, conference proceedings, interview-based works, and reviews. Provide a concise summary of the methodology used in this research. Theimportanceandapplications of the methods used in the study.  Provide a concise summary of the methodology used in this research. Provide a brief description of the methods used to conduct the study. Use this information to help students understand the results of this study. Thereare121articlesinthiscriticalreview. Thepublicationsthatwereselectedarelisted alongside the selection results. The re ...

# %% [markdown]
# ## Final Prompt

# %%
import pdfplumber
from transformers import pipeline

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
    return text

# Function to summarize text using Hugging Face transformer models (PyTorch backend)
def summarize_text_based_on_prompt(text, prompt, model="facebook/bart-large-cnn", max_length=200):
    summarizer = pipeline("summarization", model=model, framework="pt")  # Use PyTorch
    max_input_length = 1024  # Adjust based on model's max length
    text_chunks = [text[i:i+max_input_length] for i in range(0, len(text), max_input_length)]
    summaries = []
    for chunk in text_chunks:
        full_text_with_prompt = prompt + " " + chunk
        try:
            summary = summarizer(full_text_with_prompt, max_length=max_length, min_length=30, do_sample=False)
            if summary:
                summaries.append(summary[0]['summary_text'])
        except IndexError:
            summaries.append("Error: Summary index out of range.")
    return " ".join(summaries)

# Example usage
pdf_path = "/content/Blockchain_Technology_and_Artificial_Intelligence_.pdf"  # Your PDF file path
prompt = "Summaries and Analyze Insights from the research paper. "
text = extract_text_from_pdf(pdf_path)
print("Extracted text preview:")
print(text[:500])  # Print the first 500 characters to verify

summary = summarize_text_based_on_prompt(text, prompt)
print("Summary based on prompt:")
print(summary)
# Out:
# Extracted text preview:
# applied
# sciences
# Review
# Blockchain Technology and Artificial Intelligence Together: A
# Critical Review on Applications
# HamedTaherdoost
# DepartmentofArts,CommunicationsandSocialSciences,UniversityCanadaWest,Vancouver,BCV6Z0E5,
# Canada;hamed.taherdoost@gmail.com;Tel.:+1-236-889-5359
# Abstract: It is undeniable that the adoption of blockchain- and artificial intelligence (AI)-based
# paradigmsisproceedingatlightningspeed.Bothparadigmsprovidesomethingnewtothemarket,
# butthedegreeofnoveltyandcomplexityofeac
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Summary based on prompt:
# Blockchain Technology and Artificial Intelligence Together: ACritical Review on Applications. Summaries and Analyze Insights from the research paper.  applied                sciences. ThisrevelationledtoathoroughassessmentoftheAIandblockchaincombocreatedbetween2012and2022. Thiscriticalreviewcontains121articlesfromtherecentdecadethat investigate the present situation and rationale of the AI and blockchain combination. Blockchain technology has the potential to be very useful in eliminating the need for a centralauthorityfigure. Artificialintelligence(AI), whichgivesMachines the ability to learn from data, is anotherveryvisibleareathatisgainingalotoftraction. This article is an open access article. Summaries and Analyze Insights from the research paper.  informationinsmarthomes                Copyright: © 2022 by the author. The convergence of AI and blockchain could lead to the development of a new type of artificial intelligence. Blockchains may be programmed with smartcontracts, allowing trusted thirdparties to share data. Blockchain technology allowsforthesafekeepingofpatientrecords. Medicalprovidersmayaccesspatienthealthdataviathewalletwhenever needed. Integrating AI with a blockchain has been claimed to have far-reachingimplications. iverseas6Gnetworks,smartcities,banking,and driverlesscars. Withoutrelyingonacentralizedauthority orintermediaries, thisenablesthesafeandreliabledistributionoflargedatasets foranalysis,learning,anddecisionmaking. The study is to examine the state of the AI and blockchain combo. It will help emerging researchers catch up on the evolution of the field. Summaries and Analyze Insights from the research paper. At IstuWdiyth ist ahse fuoltlmowosst. Tsehreio ruessneaerscsh, aalplptrhoeacrehc uensetdp teor tfiinnedn, tfillitteerr, a atundre cwhoaosseca trheef uliltl-y-y. The RQs’ details are:. PRlaQnn2i:nWg thhaet Rseevciteowrs. The goal of this critical study was to evaluate the current state of blockchain technology. All the recent pertinent literature was carefully reviewed for this inquiry. Relevantdatabases werethoroughlysearched to provide a complete and concise evaluation of the research topics. The research paper was published in Appl. Sci. 2022, 12, x FOR PEER REVIEW. Up to now, 353 Scopus results have been analyzed. About121 were consideredimportant. A holistic review of the literature necessitated an inclusive perspective. Throughout the study, Scopus sources were examined. Relevant databases were thoroughly searched. Summaries and Analyze Insights from the research paper. Up to now, 353 Scopus results have been analyzed. For several reasons, not all outstand-                ggeennccee’” OORR ““AAII”” AANNDD � ‘“bblloocckkcchhaaiinn’ Research paper. Summaries and Analyze Insights from the research paper.  cuhhhbnnnjoeoolcllootosggg.y yyB aaaynnn ddsde AAaArIIIc... h ing “Artificial intelli-                gence••” ORTTT h“hheAee sIssc”cco ooApppNeee oDoofff “ ttthbhheleeo sscsttktuuucdddhyyya i iiinsss ” llli,iim mmreiiilttteeeevddda ttntooot ttcthhhoeeen. The resultsofansweringtheRQsgivenintheprecedingcriticalreviewfollow. Summaries and Analyze Insights from the research paper. 1. Summaries and Analyze Insights from the research paper. 2. Deisacgrriabmes otfh reesAeaIrachn dmbetlhoocdk.c haincombinationanditsfoundations,variations,de-sseeccttiioonn ddeessccrriibbeess. Research paper. Summaries and Analyze Insights from the research paper. Insights are based on the findings of the study. The study was published in the Journal of Personality and Social Psychology. It was published by Oxford University Press. Thereare121articlesinthiscriticalreview. Thepublicationsthatwereselectedarelisted. The results of employing the AI and blockchain combination will be discussed in further detail in the next section. In total, 353 items were generated by this search, and 232 of them were inspected. Computer science (84 articles) and engineering were the primary topics. The publications that were selected  ...
